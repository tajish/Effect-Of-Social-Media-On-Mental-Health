# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Loneliness.xlsx')

# %%
df.head(5)
# Out:
#   2. Which social media account do you use usually?  \
# 0                                          Facebook
# 1                                          Facebook
# 2                                          Facebook
# 3                                           Twitter
# 4                                           Twitter
#
#   3. Which device do you usually use to connect social media?  \
# 0                                       Mobile Phone
# 1                                       Mobile Phone
# 2                                       Mobile Phone
# 3                                       Mobile Phone
# 4                                       Mobile Phone
#
#   4. Which type of internet connection do you use?  \
# 0                                Broadband (Wi-Fi)
# 1                                Broadband (Wi-Fi)
# 2                                Broadband (Wi-Fi)
# 3                                      Mobile data
# 4                                Broadband (Wi-Fi)
#
#   5. How long have you been using a social media account?  \
# 0                                         5-10 years
# 1                                         5-10 years
# 2                                         5-10 years
# 3                                   Less than 2-year
# 4                                   Less than 2-year
#
#   6. How frequently do you post (upload status or add photos/videos) on social media?   \
# 0                                Less than 1 per day
# 1                                        3-5 per day
# 2                                Less than 1 per day
# 3                                Less than 1 per day
# 4                                More than 5 per day
#
#   7. How much time do you spend daily in social media?  \
# 0                                          1-3 hours
# 1                                  More than 5 hours
# 2                                          3-5 hours
# 3                                          3-5 hours
# 4                                  More than 5 hours
#
#   8. When do you usually use social media?  \
# 0                    Frequently at anytime
# 1                    Frequently at anytime
# 2                      Night to late night
# 3                    Frequently at anytime
# 4                      Night to late night
#
#   9. How many friends do you have on social media?  \
# 0                                    Less than 500
# 1                                         500-2000
# 2                                    Less than 500
# 3                                         500-2000
# 4                                        2000-4000
#
#   10. How many friends do you know personally in social media?   \
# 0                                        All of them
# 1                                        All of them
# 2                                       Many of them
# 3                                        Few of them
# 4                                       Most of them
#
#   11. How many groups you are tagged in social media?  ... 24. Religion  \
# 0                                        Less than 5   ...       Muslim
# 1                                       More than 20   ...       Muslim
# 2                                              10-20   ...       Muslim
# 3                                        Less than 5   ...        Hindu
# 4                                              10-20   ...        Hindu
#
#      25. Education                 26. Profession 27. Monthly income  \
# 0   Graduate Level                    Private job    Above 70,000 Tk
# 1   Graduate Level  Unemployed including students          No income
# 2  Secondary Level  Unemployed including students          No income
# 3  Secondary Level  Unemployed including students          No income
# 4   Graduate Level  Unemployed including students          No income
#
#   28. Area of residence 29. Living with- 30. Body weight (Kg) 31. Height (m)  \
# 0            Urban Area      With family                 34.0         1.4986
# 1            Urban Area      With family                 38.0         1.5748
# 2            Urban Area      With family                 39.0         1.5748
# 3            Rural Area   Without family                 40.0         1.5748
# 4            Rural Area      With family                 40.0         1.5748
#
#   32. Smoking habit                     Loneliness
# 0        Non-smoker       Low levels of loneliness
# 1        Non-smoker    Normal levels of loneliness
# 2        Non-smoker  Moderate levels of lineliness
# 3        Non-smoker       Low levels of loneliness
# 4            Smoker       Low levels of loneliness
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (791, 32)

# %%
sns.set_theme(style="darkgrid")

# %%
plt.figure(figsize=(25,8))
sns.countplot(x='21. Please write your age in years (number).',hue='Loneliness',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cd11de579a12> in <module>
# ----> 1 plt.figure(figsize=(25,8))
#       2 sns.countplot(x='21. Please write your age in years (number).',hue='Loneliness',data=df)
#
# NameError: name 'plt' is not defined

# %%
sns.countplot(x='Loneliness',data=df)

# %%
sns.countplot(x='32. Smoking habit',hue='Loneliness',data=df)

# %%
sns.countplot(x='27. Monthly income',hue='Loneliness',data=df)

# %%
sns.countplot(x='7. How much time do you spend daily in social media?',hue='Loneliness',data=df)

# %% [markdown]
# **Data Preprocesing**

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['2. Which social media account do you use usually?'] = label_encoder.fit_transform(df['2. Which social media account do you use usually?'])
df['2. Which social media account do you use usually?'].unique()
# Out:
# array([0, 5, 3, 2, 7, 8, 1, 6, 4])

# %%
df['3. Which device do you usually use to connect social media?'] = label_encoder.fit_transform(df['3. Which device do you usually use to connect social media?'])
df['3. Which device do you usually use to connect social media?'].unique()
# Out:
# array([2, 3, 1, 0])

# %%
df['4. Which type of internet connection do you use?'] = label_encoder.fit_transform(df['4. Which type of internet connection do you use?'])
df['4. Which type of internet connection do you use?'].unique()
# Out:
# array([0, 1])

# %%
df['5. How long have you been using a social media account?'] = label_encoder.fit_transform(df['5. How long have you been using a social media account?'])
df['5. How long have you been using a social media account?'].unique()
# Out:
# array([1, 2, 0, 3])

# %%
df['6. How frequently do you post (upload status or add photos/videos) on social media? '] = label_encoder.fit_transform(df['6. How frequently do you post (upload status or add photos/videos) on social media? '])
df['6. How frequently do you post (upload status or add photos/videos) on social media? '].unique()
# Out:
# array([2, 1, 3, 0])

# %%
df['7. How much time do you spend daily in social media?'] = label_encoder.fit_transform(df['7. How much time do you spend daily in social media?'])
df['7. How much time do you spend daily in social media?'].unique()
# Out:
# array([0, 3, 1, 2])

# %%
df['8. When do you usually use social media?'] = label_encoder.fit_transform(df['8. When do you usually use social media?'])
df['8. When do you usually use social media?'].unique()
# Out:
# array([2, 4, 1, 0, 3])

# %%
df['9. How many friends do you have on social media?'] = label_encoder.fit_transform(df['9. How many friends do you have on social media?'])
df['9. How many friends do you have on social media?'].unique()
# Out:
# array([2, 1, 0, 3])

# %%
df['10. How many friends do you know personally in social media? '] = label_encoder.fit_transform(df['10. How many friends do you know personally in social media? '])
df['10. How many friends do you know personally in social media? '].unique()
# Out:
# array([0, 2, 1, 3])

# %%
df['11. How many groups you are tagged in social media?'] = label_encoder.fit_transform(df['11. How many groups you are tagged in social media?'])
df['11. How many groups you are tagged in social media?'].unique()
# Out:
# array([2, 3, 0, 1])

# %%
df['12. What is your main purpose for using social media (e.g. Facebook)?'] = label_encoder.fit_transform(df['12. What is your main purpose for using social media (e.g. Facebook)?'])
df['12. What is your main purpose for using social media (e.g. Facebook)?'].unique()
# Out:
# array([4, 0, 3, 1, 2])

# %%
df['13. What contents do you mainly look for in your social media news feed?'] = label_encoder.fit_transform(df['13. What contents do you mainly look for in your social media news feed?'])
df['13. What contents do you mainly look for in your social media news feed?'].unique()
# Out:
# array([20, 18, 12, 19,  9, 13, 14, 11, 21,  4,  3, 17,  8,  7,  6,  5, 16,
#        15,  0, 10,  2,  1])

# %%
df['14.Do you believe social media is a good thing?'] = label_encoder.fit_transform(df['14.Do you believe social media is a good thing?'])
df['14.Do you believe social media is a good thing?'].unique()
# Out:
# array([1, 0])

# %%
df['15. When you see something in social media, do you instantly believe it?'] = label_encoder.fit_transform(df['15. When you see something in social media, do you instantly believe it?'])
df['15. When you see something in social media, do you instantly believe it?'].unique()
# Out:
# array([0, 1])

# %%
df['16. Have you ever experienced peer pressure due to social media?'] = label_encoder.fit_transform(df['16. Have you ever experienced peer pressure due to social media?'])
df['16. Have you ever experienced peer pressure due to social media?'].unique()
# Out:
# array([0, 1])

# %%
df['17. Does your emotion get influenced by others posts (success, failure, loss)? '] = label_encoder.fit_transform(df['17. Does your emotion get influenced by others posts (success, failure, loss)? '])
df['17. Does your emotion get influenced by others posts (success, failure, loss)? '].unique()
# Out:
# array([2, 1, 0])

# %%
df['18. Have you ever compared yourself with other’s success or luxurious life?'] = label_encoder.fit_transform(df['18. Have you ever compared yourself with other’s success or luxurious life?'])
df['18. Have you ever compared yourself with other’s success or luxurious life?'].unique()
# Out:
# array([2, 0, 1])

# %%
df['19. Do you think, your mental wellbeing would be better if you do not use social media?'] = label_encoder.fit_transform(df['19. Do you think, your mental wellbeing would be better if you do not use social media?'])
df['19. Do you think, your mental wellbeing would be better if you do not use social media?'].unique()
# Out:
# array([0, 1])

# %%
df['20. If answer is yes, are you trying to control that thing and trying to reduce the use of social media?'] = label_encoder.fit_transform(df['20. If answer is yes, are you trying to control that thing and trying to reduce the use of social media?'])
df['20. If answer is yes, are you trying to control that thing and trying to reduce the use of social media?'].unique()
# Out:
# array([1, 2, 3, 0, 4, 5])

# %%
df['22. Gender'] = label_encoder.fit_transform(df['22. Gender'])
df['22. Gender'].unique()
# Out:
# array([0, 1])

# %%
df['23. Marital Status'] = label_encoder.fit_transform(df['23. Marital Status'])
df['23. Marital Status'].unique()
# Out:
# array([1, 2, 0, 3])

# %%
df['24. Religion'] = label_encoder.fit_transform(df['24. Religion'])
df['24. Religion'].unique()
# Out:
# array([ 9,  7,  3, 10, 13,  4, 12,  0,  5,  6,  2,  8, 11,  1])

# %%
df['25. Education'] = label_encoder.fit_transform(df['25. Education'])
df['25. Education'].unique()
# Out:
# array([0, 5, 4, 3, 1, 2, 6])

# %%
df['26. Profession'] = label_encoder.fit_transform(df['26. Profession'])
df['26. Profession'].unique()
# Out:
# array([20, 28, 25, 23, 16, 15,  4, 17,  9,  8, 10, 19, 31,  3, 24, 14, 18,
#        30,  7, 26, 29,  6, 11, 27,  5, 21, 13, 22,  0,  2, 12,  1])

# %%
df['27. Monthly income'] = label_encoder.fit_transform(df['27. Monthly income'])
df['27. Monthly income'].unique()
# Out:
# array([2, 3, 0, 1])

# %%
df['28. Area of residence'] = label_encoder.fit_transform(df['28. Area of residence'])
df['28. Area of residence'].unique()
# Out:
# array([1, 0])

# %%
df['29. Living with-'] = label_encoder.fit_transform(df['29. Living with-'])
df['29. Living with-'].unique()
# Out:
# array([0, 1])

# %%
df['32. Smoking habit'] = label_encoder.fit_transform(df['32. Smoking habit'])
df['32. Smoking habit'].unique()
# Out:
# array([0, 1])

# %%
df.head(15)
# Out:
#     2. Which social media account do you use usually?  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   5
# 4                                                   5
# 5                                                   0
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                   0
# 10                                                  0
# 11                                                  3
# 12                                                  0
# 13                                                  0
# 14                                                  0
#
#     3. Which device do you usually use to connect social media?  \
# 0                                                   2
# 1                                                   2
# 2                                                   2
# 3                                                   2
# 4                                                   2
# 5                                                   3
# 6                                                   1
# 7                                                   2
# 8                                                   2
# 9                                                   2
# 10                                                  0
# 11                                                  2
# 12                                                  2
# 13                                                  3
# 14                                                  2
#
#     4. Which type of internet connection do you use?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
# 5                                                  1
# 6                                                  0
# 7                                                  0
# 8                                                  0
# 9                                                  0
# 10                                                 0
# 11                                                 1
# 12                                                 1
# 13                                                 0
# 14                                                 0
#
#     5. How long have you been using a social media account?  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   2
# 4                                                   2
# 5                                                   0
# 6                                                   0
# 7                                                   1
# 8                                                   0
# 9                                                   3
# 10                                                  0
# 11                                                  2
# 12                                                  2
# 13                                                  2
# 14                                                  1
#
#     6. How frequently do you post (upload status or add photos/videos) on social media?   \
# 0                                                   2
# 1                                                   1
# 2                                                   2
# 3                                                   2
# 4                                                   3
# 5                                                   0
# 6                                                   0
# 7                                                   2
# 8                                                   2
# 9                                                   3
# 10                                                  0
# 11                                                  3
# 12                                                  0
# 13                                                  0
# 14                                                  2
#
#     7. How much time do you spend daily in social media?  \
# 0                                                   0
# 1                                                   3
# 2                                                   1
# 3                                                   1
# 4                                                   3
# 5                                                   2
# 6                                                   0
# 7                                                   0
# 8                                                   1
# 9                                                   0
# 10                                                  0
# 11                                                  3
# 12                                                  3
# 13                                                  0
# 14                                                  1
#
#     8. When do you usually use social media?  \
# 0                                          2
# 1                                          2
# 2                                          4
# 3                                          2
# 4                                          4
# 5                                          1
# 6                                          0
# 7                                          2
# 8                                          4
# 9                                          1
# 10                                         1
# 11                                         1
# 12                                         2
# 13                                         4
# 14                                         0
#
#     9. How many friends do you have on social media?  \
# 0                                                  2
# 1                                                  1
# 2                                                  2
# 3                                                  1
# 4                                                  0
# 5                                                  1
# 6                                                  1
# 7                                                  1
# 8                                                  1
# 9                                                  1
# 10                                                 1
# 11                                                 2
# 12                                                 2
# 13                                                 2
# 14                                                 2
#
#     10. How many friends do you know personally in social media?   \
# 0                                                   0
# 1                                                   0
# 2                                                   2
# 3                                                   1
# 4                                                   3
# 5                                                   1
# 6                                                   3
# 7                                                   3
# 8                                                   2
# 9                                                   1
# 10                                                  2
# 11                                                  0
# 12                                                  2
# 13                                                  1
# 14                                                  3
#
#     11. How many groups you are tagged in social media?  ...  24. Religion  \
# 0                                                   2    ...             9
# 1                                                   3    ...             9
# 2                                                   0    ...             9
# 3                                                   2    ...             7
# 4                                                   0    ...             7
# 5                                                   1    ...             9
# 6                                                   1    ...             3
# 7                                                   3    ...             9
# 8                                                   3    ...             9
# 9                                                   2    ...             9
# 10                                                  1    ...             9
# 11                                                  2    ...             9
# 12                                                  1    ...             9
# 13                                                  2    ...             9
# 14                                                  2    ...             9
#
#     25. Education  26. Profession  27. Monthly income  28. Area of residence  \
# 0               0              20                   2                      1
# 1               0              28                   3                      1
# 2               5              28                   3                      1
# 3               5              28                   3                      0
# 4               0              28                   3                      0
# 5               5              28                   3                      0
# 6               5              28                   3                      0
# 7               0              20                   0                      1
# 8               5              28                   3                      1
# 9               0              20                   0                      1
# 10              4              28                   3                      0
# 11              5              28                   3                      0
# 12              5              28                   3                      0
# 13              5              28                   3                      1
# 14              3              25                   3                      1
#
#     29. Living with-  30. Body weight (Kg)  31. Height (m)  32. Smoking habit  \
# 0                  0                  34.0          1.4986                  0
# 1                  0                  38.0          1.5748                  0
# 2                  0                  39.0          1.5748                  0
# 3                  1                  40.0          1.5748                  0
# 4                  0                  40.0          1.5748                  1
# 5                  0                  40.0          1.5748                  0
# 6                  0                  44.0          1.6510                  1
# 7                  0                  59.0          1.9050                  0
# 8                  0                  50.0          1.7526                  0
# 9                  0                  45.0          1.6510                  0
# 10                 0                  40.0          1.5494                  0
# 11                 0                  40.0          1.5494                  0
# 12                 0                  40.0          1.5494                  0
# 13                 0                  40.0          1.5494                  0
# 14                 0                  42.0          1.5748                  0
#
#                        Loneliness
# 0        Low levels of loneliness
# 1     Normal levels of loneliness
# 2   Moderate levels of lineliness
# 3        Low levels of loneliness
# 4        Low levels of loneliness
# 5        Low levels of loneliness
# 6        Low levels of loneliness
# 7        Low levels of loneliness
# 8        Low levels of loneliness
# 9        Low levels of loneliness
# 10       Low levels of loneliness
# 11       Low levels of loneliness
# 12       Low levels of loneliness
# 13       Low levels of loneliness
# 14       Low levels of loneliness
#
# [15 rows x 32 columns]

# %% [markdown]
# Feature Selection Via **Chi Squire** Test

# %%
x = df.drop('Loneliness',axis=1)

# %%
x
# Out:
#      2. Which social media account do you use usually?  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 786                                                  0
# 787                                                  0
# 788                                                  0
# 789                                                  0
# 790                                                  4
#
#      3. Which device do you usually use to connect social media?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 786                                                  2
# 787                                                  2
# 788                                                  2
# 789                                                  2
# 790                                                  2
#
#      4. Which type of internet connection do you use?  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 786                                                 0
# 787                                                 0
# 788                                                 0
# 789                                                 0
# 790                                                 0
#
#      5. How long have you been using a social media account?  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 786                                                  3
# 787                                                  1
# 788                                                  1
# 789                                                  0
# 790                                                  3
#
#      6. How frequently do you post (upload status or add photos/videos) on social media?   \
# 0                                                    2
# 1                                                    1
# 2                                                    2
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 786                                                  2
# 787                                                  2
# 788                                                  3
# 789                                                  2
# 790                                                  2
#
#      7. How much time do you spend daily in social media?  \
# 0                                                    0
# 1                                                    3
# 2                                                    1
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 786                                                  0
# 787                                                  2
# 788                                                  1
# 789                                                  0
# 790                                                  0
#
#      8. When do you usually use social media?  \
# 0                                           2
# 1                                           2
# 2                                           4
# 3                                           2
# 4                                           4
# ..                                        ...
# 786                                         4
# 787                                         2
# 788                                         2
# 789                                         1
# 790                                         1
#
#      9. How many friends do you have on social media?  \
# 0                                                   2
# 1                                                   1
# 2                                                   2
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 786                                                 2
# 787                                                 2
# 788                                                 1
# 789                                                 2
# 790                                                 2
#
#      10. How many friends do you know personally in social media?   \
# 0                                                    0
# 1                                                    0
# 2                                                    2
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 786                                                  0
# 787                                                  2
# 788                                                  0
# 789                                                  3
# 790                                                  3
#
#      11. How many groups you are tagged in social media?  ...  \
# 0                                                    2    ...
# 1                                                    3    ...
# 2                                                    0    ...
# 3                                                    2    ...
# 4                                                    0    ...
# ..                                                 ...    ...
# 786                                                  1    ...
# 787                                                  2    ...
# 788                                                  0    ...
# 789                                                  2    ...
# 790                                                  1    ...
#
#      23. Marital Status  24. Religion  25. Education  26. Profession  \
# 0                     1             9              0              20
# 1                     2             9              0              28
# 2                     2             9              5              28
# 3                     2             7              5              28
# 4                     2             7              0              28
# ..                  ...           ...            ...             ...
# 786                   2             9              3              20
# 787                   2             9              3              28
# 788                   2             9              0              28
# 789                   2             9              0              28
# 790                   2             1              0              20
#
#      27. Monthly income  28. Area of residence  29. Living with-  \
# 0                     2                      1                 0
# 1                     3                      1                 0
# 2                     3                      1                 0
# 3                     3                      0                 1
# 4                     3                      0                 0
# ..                  ...                    ...               ...
# 786                   0                      1                 0
# 787                   3                      1                 0
# 788                   3                      1                 0
# 789                   3                      1                 0
# 790                   1                      1                 1
#
#      30. Body weight (Kg)  31. Height (m)  32. Smoking habit
# 0                    34.0          1.4986                  0
# 1                    38.0          1.5748                  0
# 2                    39.0          1.5748                  0
# 3                    40.0          1.5748                  0
# 4                    40.0          1.5748                  1
# ..                    ...             ...                ...
# 786                  85.0          1.4690                  0
# 787                  98.0          1.5748                  0
# 788                 100.0          1.5494                  0
# 789                  65.0          1.2446                  0
# 790                 110.0          1.5494                  0
#
# [791 rows x 31 columns]

# %%
y = df['Loneliness']

# %%
y
# Out:
# 0           Low levels of loneliness
# 1        Normal levels of loneliness
# 2      Moderate levels of lineliness
# 3           Low levels of loneliness
# 4           Low levels of loneliness
#                    ...
# 786         Low levels of loneliness
# 787      Normal levels of loneliness
# 788      Normal levels of loneliness
# 789         Low levels of loneliness
# 790         Low levels of loneliness
# Name: Loneliness, Length: 791, dtype: object

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
FIT_FEATURES = SelectKBest(score_func=chi2)

# %%
FIT_FEATURES.fit(x,y)
# Out:
# SelectKBest(score_func=<function chi2 at 0x7ff174eb9ca0>)

# %%
SCORE_COL = pd.DataFrame(FIT_FEATURES.scores_,columns = ['score value'])

# %%
NAME_COL = pd.DataFrame(x.columns)

# %%
topr_features = pd.concat([NAME_COL,SCORE_COL],axis=1)
topr_features.columns = ['Top Features','Score']

# %%
topr_features
# Out:
#                                          Top Features         Score
# 0   2. Which social media account do you use usually?  1.176930e+00
# 1   3. Which device do you usually use to connect ...  1.376181e-01
# 2    4. Which type of internet connection do you use?  5.697521e+00
# 3   5. How long have you been using a social media...  4.948332e-01
# 4   6. How frequently do you post (upload status o...  4.720696e-01
# 5   7. How much time do you spend daily in social ...  1.759150e+01
# 6            8. When do you usually use social media?  1.156378e+00
# 7    9. How many friends do you have on social media?  3.593516e-02
# 8   10. How many friends do you know personally in...  7.392611e-01
# 9   11. How many groups you are tagged in social m...  5.354367e-01
# 10  12. What is your main purpose for using social...  7.872242e+00
# 11  13. What contents do you mainly look for in yo...  1.804235e+01
# 12    14.Do you believe social media is a good thing?  5.087824e+00
# 13  15. When you see something in social media, do...  1.133236e+00
# 14  16. Have you ever experienced peer pressure du...  4.070176e+00
# 15  17. Does your emotion get influenced by others...  3.888103e+00
# 16  18. Have you ever compared yourself with other...  6.853971e+00
# 17  19. Do you think, your mental wellbeing would ...  3.736694e+00
# 18  20. If answer is yes, are you trying to contro...  4.248289e-01
# 19       21. Please write your age in years (number).  1.416898e+12
# 20                                         22. Gender  1.452522e+00
# 21                                 23. Marital Status  3.312531e-01
# 22                                       24. Religion  2.194475e-02
# 23                                      25. Education  6.097561e-02
# 24                                     26. Profession  1.029735e+01
# 25                                 27. Monthly income  3.669152e+00
# 26                              28. Area of residence  9.275892e-01
# 27                                   29. Living with-  3.117292e+00
# 28                               30. Body weight (Kg)  2.197180e+01
# 29                                     31. Height (m)  1.601605e-02
# 30                                  32. Smoking habit  1.949704e+00

# %%
topr_features.nlargest(33,'Score')
# Out:
#                                          Top Features         Score
# 19       21. Please write your age in years (number).  1.416898e+12
# 28                               30. Body weight (Kg)  2.197180e+01
# 11  13. What contents do you mainly look for in yo...  1.804235e+01
# 5   7. How much time do you spend daily in social ...  1.759150e+01
# 24                                     26. Profession  1.029735e+01
# 10  12. What is your main purpose for using social...  7.872242e+00
# 16  18. Have you ever compared yourself with other...  6.853971e+00
# 2    4. Which type of internet connection do you use?  5.697521e+00
# 12    14.Do you believe social media is a good thing?  5.087824e+00
# 14  16. Have you ever experienced peer pressure du...  4.070176e+00
# 15  17. Does your emotion get influenced by others...  3.888103e+00
# 17  19. Do you think, your mental wellbeing would ...  3.736694e+00
# 25                                 27. Monthly income  3.669152e+00
# 27                                   29. Living with-  3.117292e+00
# 30                                  32. Smoking habit  1.949704e+00
# 20                                         22. Gender  1.452522e+00
# 0   2. Which social media account do you use usually?  1.176930e+00
# 6            8. When do you usually use social media?  1.156378e+00
# 13  15. When you see something in social media, do...  1.133236e+00
# 26                              28. Area of residence  9.275892e-01
# 8   10. How many friends do you know personally in...  7.392611e-01
# 9   11. How many groups you are tagged in social m...  5.354367e-01
# 3   5. How long have you been using a social media...  4.948332e-01
# 4   6. How frequently do you post (upload status o...  4.720696e-01
# 18  20. If answer is yes, are you trying to contro...  4.248289e-01
# 21                                 23. Marital Status  3.312531e-01
# 1   3. Which device do you usually use to connect ...  1.376181e-01
# 23                                      25. Education  6.097561e-02
# 7    9. How many friends do you have on social media?  3.593516e-02
# 22                                       24. Religion  2.194475e-02
# 29                                     31. Height (m)  1.601605e-02

# %%
df = df.drop(['31. Height (m)','24. Religion','9. How many friends do you have on social media?','25. Education','3. Which device do you usually use to connect social media?','23. Marital Status','20. If answer is yes, are you trying to control that thing and trying to reduce the use of social media?','6. How frequently do you post (upload status or add photos/videos) on social media? ','5. How long have you been using a social media account?','11. How many groups you are tagged in social media?','10. How many friends do you know personally in social media? ','28. Area of residence'],axis =1)

# %%
df
# Out:
#      2. Which social media account do you use usually?  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 786                                                  0
# 787                                                  0
# 788                                                  0
# 789                                                  0
# 790                                                  4
#
#      4. Which type of internet connection do you use?  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   1
# 4                                                   0
# ..                                                ...
# 786                                                 0
# 787                                                 0
# 788                                                 0
# 789                                                 0
# 790                                                 0
#
#      7. How much time do you spend daily in social media?  \
# 0                                                    0
# 1                                                    3
# 2                                                    1
# 3                                                    1
# 4                                                    3
# ..                                                 ...
# 786                                                  0
# 787                                                  2
# 788                                                  1
# 789                                                  0
# 790                                                  0
#
#      8. When do you usually use social media?  \
# 0                                           2
# 1                                           2
# 2                                           4
# 3                                           2
# 4                                           4
# ..                                        ...
# 786                                         4
# 787                                         2
# 788                                         2
# 789                                         1
# 790                                         1
#
#      12. What is your main purpose for using social media (e.g. Facebook)?  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 786                                                  4
# 787                                                  4
# 788                                                  4
# 789                                                  4
# 790                                                  4
#
#      13. What contents do you mainly look for in your social media news feed?  \
# 0                                                   20
# 1                                                   18
# 2                                                   12
# 3                                                   19
# 4                                                    9
# ..                                                 ...
# 786                                                  9
# 787                                                 20
# 788                                                 18
# 789                                                 20
# 790                                                  9
#
#      14.Do you believe social media is a good thing?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# ..                                               ...
# 786                                                1
# 787                                                0
# 788                                                1
# 789                                                1
# 790                                                1
#
#      15. When you see something in social media, do you instantly believe it?  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 786                                                  0
# 787                                                  0
# 788                                                  0
# 789                                                  0
# 790                                                  0
#
#      16. Have you ever experienced peer pressure due to social media?  \
# 0                                                    0
# 1                                                    0
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 786                                                  1
# 787                                                  0
# 788                                                  0
# 789                                                  1
# 790                                                  0
#
#      17. Does your emotion get influenced by others posts (success, failure, loss)?   \
# 0                                                    2
# 1                                                    2
# 2                                                    1
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 786                                                  2
# 787                                                  2
# 788                                                  1
# 789                                                  2
# 790                                                  2
#
#      18. Have you ever compared yourself with other’s success or luxurious life?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 786                                                  2
# 787                                                  1
# 788                                                  2
# 789                                                  2
# 790                                                  2
#
#      19. Do you think, your mental wellbeing would be better if you do not use social media?  \
# 0                                                    0
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 786                                                  0
# 787                                                  1
# 788                                                  0
# 789                                                  0
# 790                                                  0
#
#      21. Please write your age in years (number).  22. Gender  26. Profession  \
# 0                                            26.0           0              20
# 1                                            24.0           0              28
# 2                                            18.0           0              28
# 3                                            17.0           0              28
# 4                                            23.0           0              28
# ..                                            ...         ...             ...
# 786                                          26.0           1              20
# 787                                          28.0           0              28
# 788                                          20.0           1              28
# 789                                          21.0           0              28
# 790                                          30.0           0              20
#
#      27. Monthly income  29. Living with-  30. Body weight (Kg)  \
# 0                     2                 0                  34.0
# 1                     3                 0                  38.0
# 2                     3                 0                  39.0
# 3                     3                 1                  40.0
# 4                     3                 0                  40.0
# ..                  ...               ...                   ...
# 786                   0                 0                  85.0
# 787                   3                 0                  98.0
# 788                   3                 0                 100.0
# 789                   3                 0                  65.0
# 790                   1                 1                 110.0
#
#      32. Smoking habit                     Loneliness
# 0                    0       Low levels of loneliness
# 1                    0    Normal levels of loneliness
# 2                    0  Moderate levels of lineliness
# 3                    0       Low levels of loneliness
# 4                    1       Low levels of loneliness
# ..                 ...                            ...
# 786                  0       Low levels of loneliness
# 787                  0    Normal levels of loneliness
# 788                  0    Normal levels of loneliness
# 789                  0       Low levels of loneliness
# 790                  0       Low levels of loneliness
#
# [791 rows x 20 columns]

# %%
x = df.drop('Loneliness',axis=1)
y = df['Loneliness']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.10,random_state=10)

# %%
xtest
# Out:
#      2. Which social media account do you use usually?  \
# 124                                                  0
# 384                                                  2
# 163                                                  8
# 52                                                   0
# 27                                                   0
# ..                                                 ...
# 64                                                   0
# 743                                                  0
# 511                                                  0
# 771                                                  0
# 188                                                  0
#
#      4. Which type of internet connection do you use?  \
# 124                                                 0
# 384                                                 0
# 163                                                 0
# 52                                                  0
# 27                                                  0
# ..                                                ...
# 64                                                  0
# 743                                                 0
# 511                                                 0
# 771                                                 0
# 188                                                 0
#
#      7. How much time do you spend daily in social media?  \
# 124                                                  3
# 384                                                  3
# 163                                                  2
# 52                                                   0
# 27                                                   0
# ..                                                 ...
# 64                                                   3
# 743                                                  3
# 511                                                  3
# 771                                                  1
# 188                                                  1
#
#      8. When do you usually use social media?  \
# 124                                         2
# 384                                         1
# 163                                         4
# 52                                          2
# 27                                          3
# ..                                        ...
# 64                                          2
# 743                                         2
# 511                                         2
# 771                                         2
# 188                                         2
#
#      12. What is your main purpose for using social media (e.g. Facebook)?  \
# 124                                                  1
# 384                                                  4
# 163                                                  4
# 52                                                   4
# 27                                                   4
# ..                                                 ...
# 64                                                   4
# 743                                                  0
# 511                                                  4
# 771                                                  4
# 188                                                  4
#
#      13. What contents do you mainly look for in your social media news feed?  \
# 124                                                  9
# 384                                                 18
# 163                                                 21
# 52                                                   9
# 27                                                  18
# ..                                                 ...
# 64                                                  18
# 743                                                 19
# 511                                                  9
# 771                                                 12
# 188                                                 18
#
#      14.Do you believe social media is a good thing?  \
# 124                                                0
# 384                                                1
# 163                                                1
# 52                                                 1
# 27                                                 1
# ..                                               ...
# 64                                                 1
# 743                                                0
# 511                                                0
# 771                                                0
# 188                                                1
#
#      15. When you see something in social media, do you instantly believe it?  \
# 124                                                  0
# 384                                                  1
# 163                                                  1
# 52                                                   0
# 27                                                   0
# ..                                                 ...
# 64                                                   1
# 743                                                  0
# 511                                                  1
# 771                                                  0
# 188                                                  0
#
#      16. Have you ever experienced peer pressure due to social media?  \
# 124                                                  0
# 384                                                  1
# 163                                                  0
# 52                                                   0
# 27                                                   0
# ..                                                 ...
# 64                                                   0
# 743                                                  1
# 511                                                  0
# 771                                                  1
# 188                                                  1
#
#      17. Does your emotion get influenced by others posts (success, failure, loss)?   \
# 124                                                  2
# 384                                                  0
# 163                                                  1
# 52                                                   2
# 27                                                   1
# ..                                                 ...
# 64                                                   2
# 743                                                  0
# 511                                                  0
# 771                                                  2
# 188                                                  2
#
#      18. Have you ever compared yourself with other’s success or luxurious life?  \
# 124                                                  1
# 384                                                  2
# 163                                                  2
# 52                                                   2
# 27                                                   0
# ..                                                 ...
# 64                                                   2
# 743                                                  0
# 511                                                  0
# 771                                                  1
# 188                                                  2
#
#      19. Do you think, your mental wellbeing would be better if you do not use social media?  \
# 124                                                  1
# 384                                                  1
# 163                                                  0
# 52                                                   0
# 27                                                   0
# ..                                                 ...
# 64                                                   0
# 743                                                  1
# 511                                                  1
# 771                                                  1
# 188                                                  1
#
#      21. Please write your age in years (number).  22. Gender  26. Profession  \
# 124                                          24.0           0              28
# 384                                          18.0           1              28
# 163                                          30.0           0              31
# 52                                           27.0           0              20
# 27                                           34.0           0              16
# ..                                            ...         ...             ...
# 64                                           20.0           1              28
# 743                                          26.0           0              20
# 511                                          35.0           1              20
# 771                                          27.0           0              28
# 188                                          30.0           0              20
#
#      27. Monthly income  29. Living with-  30. Body weight (Kg)  \
# 124                   3                 0                  45.0
# 384                   3                 1                  66.0
# 163                   3                 0                  48.0
# 52                    0                 0                  45.0
# 27                    3                 0                  41.0
# ..                  ...               ...                   ...
# 64                    3                 0                  50.0
# 743                   0                 0                  80.0
# 511                   1                 0                  78.0
# 771                   3                 0                  54.0
# 188                   2                 0                  52.0
#
#      32. Smoking habit
# 124                  0
# 384                  0
# 163                  0
# 52                   0
# 27                   0
# ..                 ...
# 64                   0
# 743                  0
# 511                  1
# 771                  0
# 188                  0
#
# [80 rows x 19 columns]

# %%
ytest
# Out:
# 124         Low levels of loneliness
# 384      Normal levels of loneliness
# 163      Normal levels of loneliness
# 52       Normal levels of loneliness
# 27          Low levels of loneliness
#                    ...
# 64       Normal levels of loneliness
# 743    Moderate levels of lineliness
# 511    Moderate levels of lineliness
# 771      Normal levels of loneliness
# 188         Low levels of loneliness
# Name: Loneliness, Length: 80, dtype: object

# %% [markdown]
# ## **MACHINE LEARNING ALGORITHM**

# %% [markdown]
# # **Decision tree**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.10,random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
clf.predict(xtest)
# Out:
# array(['Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Moderate levels of lineliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Moderate levels of lineliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Moderate levels of lineliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Moderate levels of lineliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Moderate levels of lineliness', 'Low levels of loneliness'],
#       dtype=object)

# %%
clf.score(xtest,ytest)
# Out:
# 0.575

# %%
pred_tree = clf.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_tree)
# Out:
# 0.575

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,pred_tree))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.74      0.70      0.72        56
# Moderate levels of lineliness       0.00      0.00      0.00         4
#   Normal levels of loneliness       0.32      0.35      0.33        20
#
#                      accuracy                           0.57        80
#                     macro avg       0.35      0.35      0.35        80
#                  weighted avg       0.59      0.57      0.58        80

# %% [markdown]
# # **Random forest**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.1,random_state=10)

# %%
from sklearn.ensemble import RandomForestClassifier
rclf = RandomForestClassifier()

# %%
# n_estimators = [5,20,50,100] # number of trees in the random forest
# max_features = ['auto'] # number of features in consideration at every split
# max_depth = [int(x) for x in np.linspace(10, 120, num = 12)] # maximum number of levels allowed in each decision tree
# min_samples_split = [2 ,4 ,6, 10 , 12] # minimum sample number to split a node
# min_samples_leaf = [1, 3, 4 , 8 ,10 ] # minimum sample number that can be stored in a leaf node
# bootstrap = [True, False] # method used to sample data points
# random_grid = {'n_estimators': n_estimators,

# 'max_features': max_features,

# 'max_depth': max_depth,

# 'min_samples_split': min_samples_split,

# 'min_samples_leaf': min_samples_leaf,

# 'bootstrap': bootstrap }

# %%
# from sklearn.model_selection import RandomizedSearchCV
# rf_random = RandomizedSearchCV ( estimator = rclf,param_distributions = random_grid,
#                n_iter = 100, cv = 7, verbose=2, random_state=35, n_jobs = -1)
# rclf.fit(xtrain, ytrain)

# %%
# print ('Random grid: ', random_grid, '\n')
# # print the best parameters
# print ('Best Parameters: ', rf_random.best_params_, ' \n')

# %%
rclf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
# randmf = RandomForestClassifier(n_estimators = 100, min_samples_split = 6, min_samples_leaf= 4, max_features = 'sqrt', max_depth= 120, bootstrap=False) 
# randmf.fit( xtrain, ytrain)

# %%
y_pred_rf1 = pd.DataFrame( { "actual": ytest, 
"predicted_prob": rclf.predict( 
( xtest ) ) } ) 
y_pred_rf1
# Out:
#                             actual               predicted_prob
# 124       Low levels of loneliness  Normal levels of loneliness
# 384    Normal levels of loneliness     Low levels of loneliness
# 163    Normal levels of loneliness     Low levels of loneliness
# 52     Normal levels of loneliness     Low levels of loneliness
# 27        Low levels of loneliness     Low levels of loneliness
# ..                             ...                          ...
# 64     Normal levels of loneliness     Low levels of loneliness
# 743  Moderate levels of lineliness  Normal levels of loneliness
# 511  Moderate levels of lineliness  Normal levels of loneliness
# 771    Normal levels of loneliness     Low levels of loneliness
# 188       Low levels of loneliness     Low levels of loneliness
#
# [80 rows x 2 columns]

# %%
rclf.predict(xtest)
# Out:
# array(['Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness'],
#       dtype=object)

# %%
rclf.score(xtest,ytest)
# Out:
# 0.6125

# %%
pred_tree = rclf.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_tree)
# Out:
# 0.6125

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,pred_tree))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.71      0.82      0.76        56
# Moderate levels of lineliness       0.00      0.00      0.00         4
#   Normal levels of loneliness       0.20      0.15      0.17        20
#
#                      accuracy                           0.61        80
#                     macro avg       0.30      0.32      0.31        80
#                  weighted avg       0.55      0.61      0.58        80
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **SVM**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.1,random_state=50)

# %%
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler(feature_range=(-1,1)).fit(xtrain)
xtrain = scaling.transform(xtrain)
xtest = scaling.transform(xtest)

from sklearn import svm

# %%
classif = svm.SVC( kernel = 'rbf', gamma='scale' , C=2)

classif.fit(xtrain,ytrain)
# Out:
# SVC(C=10)

# %%
y_predict = classif.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,y_predict))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.73      0.86      0.79        57
# Moderate levels of lineliness       0.50      0.33      0.40         3
#   Normal levels of loneliness       0.18      0.10      0.13        20
#
#                      accuracy                           0.65        80
#                     macro avg       0.47      0.43      0.44        80
#                  weighted avg       0.59      0.65      0.61        80

# %%
# from sklearn.model_selection import train_test_split
# xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.1,random_state=50)

# from sklearn.preprocessing import MinMaxScaler
# scaling = MinMaxScaler(feature_range=(-1,1)).fit(xtrain)
# xtrain = scaling.transform(xtrain)
# xtest = scaling.transform(xtest)

# from sklearn import svm

# classif = svm.SVC( kernel = 'rbf', gamma='scale' , C=2 )

# classif.fit(xtrain,ytrain)


# pred_tree = classif.predict(xtest)

# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(ytest,pred_tree)
# from sklearn.metrics import ConfusionMatrixDisplay
# cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
# fig, ax = plt.subplots(figsize=(10,10))
# cmp.plot(ax=ax)


# from sklearn.metrics import classification_report

# print(classification_report(ytest,pred_tree))

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import validation_curve

# %%
param_range = np.logspace(-6, -1, 5)
train_scores, test_scores = validation_curve(svm.SVC(),
    x,
    y,
    param_name="gamma",
    param_range=param_range,
    scoring="accuracy",
    n_jobs=2,
)

# %%
    # Calculating mean and standard deviation for training set scores
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)

    # Calculating mean and standard deviation for test set scores
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    # Plotting mean accuracy scores for training and test sets
    plt.subplots(1, figsize=(7,7))
    plt.plot(param_range, train_mean, label="Training score", color = 'b')
    plt.plot(param_range, test_mean, label="Cross-validation score", color = 'g')

    # Plotting accurancy bands for training and test sets
    #plt.fill_between(param_range, train_mean - train_std, train_mean + train_std, color="gray")
    # plt.fill_between(param_range, test_mean - test_std, test_mean + test_std, color="gainsboro")

    # Creating plot    
    plt.title("Validation Curve With SVM")
    plt.xlabel("Number Of Trees")
    plt.ylabel("Accuracy Score")
    plt.tight_layout()
    plt.legend(loc="best")
    plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split as tts
from yellowbrick.classifier import PrecisionRecallCurve
from yellowbrick.datasets import load_game

# %%
X = OrdinalEncoder().fit_transform(x)
encoder = LabelEncoder()
Y = encoder.fit_transform(y)

X_train, X_test, y_train, y_test = tts(X, Y, test_size=0.2, shuffle=True)

# %%
viz = PrecisionRecallCurve(
    svm.SVC(),
classes=encoder.classes_,
    colors=["purple", "cyan", "blue"],
    iso_f1_curves=True,
    per_class=True,
    micro=False
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show()

# %% [markdown]
# # **ADA**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.10,random_state=10)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_classification

# %%
ada = AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
ada.fit(xtrain,ytrain)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
ada.predict(xtest)
# Out:
# array(['Normal levels of loneliness', 'Moderate levels of lineliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Moderate levels of lineliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Moderate levels of lineliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness'],
#       dtype=object)

# %%
ada.score(xtest,ytest)
# Out:
# 0.6

# %%
pred_tree = ada.predict(xtest)
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_tree)
# Out:
# 0.6

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,pred_tree))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.72      0.79      0.75        56
# Moderate levels of lineliness       0.00      0.00      0.00         4
#   Normal levels of loneliness       0.25      0.20      0.22        20
#
#                      accuracy                           0.60        80
#                     macro avg       0.32      0.33      0.32        80
#                  weighted avg       0.57      0.60      0.58        80

# %% [markdown]
# # **KNN**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.10,random_state=10)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(xtrain,ytrain)
 pred_i = knn.predict(xtest)
 error_rate.append(np.mean(pred_i != ytest))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# Minimum error:- 0.3 at K = 8

# %%
acc = []
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(xtrain,ytrain)
    yhat = neigh.predict(xtest)
    acc.append(metrics.accuracy_score(ytest, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
n = acc.index(max(acc))
# Out:
# Maximum accuracy:- 0.7 at K = 8

# %%
neigh = KNeighborsClassifier(n_neighbors=n)

# %%
neigh.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
neigh.predict(xtest)
# Out:
# array(['Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness'],
#       dtype=object)

# %%
pred_tree = neigh.predict(xtest)
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_tree)
# Out:
# 0.65

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,pred_tree))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.68      0.93      0.79        56
# Moderate levels of lineliness       0.00      0.00      0.00         4
#   Normal levels of loneliness       0.00      0.00      0.00        20
#
#                      accuracy                           0.65        80
#                     macro avg       0.23      0.31      0.26        80
#                  weighted avg       0.48      0.65      0.55        80
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **Naive bayes**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.10,random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(xtrain)
X_test = sc.transform(xtest)
# X_train = xtrain
# X_test = xtest

# %%
from sklearn.naive_bayes import GaussianNB
gs = GaussianNB()
gs.fit(X_train, ytrain)
# Out:
# GaussianNB()

# %%
gs.predict(X_test)
# Out:
# array(['Normal levels of loneliness', 'Moderate levels of lineliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Moderate levels of lineliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Moderate levels of lineliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Moderate levels of lineliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Moderate levels of lineliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness'],
#       dtype='<U29')

# %%
gs.score(X_test,ytest)
# Out:
# 0.2125

# %%
pred_tree = gs.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_tree)
# Out:
# 0.2125

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,pred_tree))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.00      0.00      0.00        56
# Moderate levels of lineliness       0.00      0.00      0.00         4
#   Normal levels of loneliness       0.23      0.85      0.36        20
#
#                      accuracy                           0.21        80
#                     macro avg       0.08      0.28      0.12        80
#                  weighted avg       0.06      0.21      0.09        80
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # **ensemble**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.10,random_state=10)

# %%
from sklearn.ensemble import VotingClassifier

clf1 = DecisionTreeClassifier(random_state=42)
clf2 = RandomForestClassifier(n_estimators = 100, min_samples_split = 6, min_samples_leaf= 4, max_features = 'sqrt', max_depth= 120, bootstrap=False)
clf3 = svm.SVC( kernel = 'rbf', gamma='scale' , C=10 )


eclf1 = VotingClassifier ( estimators=[('Decision tree',clf1),('random forest',clf2),('svm',clf3)] , voting ='hard' )
eclf1.fit(xtrain,ytrain)
# Out:
# VotingClassifier(estimators=[('Decision tree',
#                               DecisionTreeClassifier(random_state=42)),
#                              ('random forest',
#                               RandomForestClassifier(bootstrap=False,
#                                                      max_depth=120,
#                                                      max_features='sqrt',
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=6)),
#                              ('svm', SVC(C=10))])

# %%
eclf1.predict(xtest)
# Out:
# array(['Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness'],
#       dtype=object)

# %%
pred_tree = eclf1.predict(xtest)
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_tree)
# Out:
# 0.6875

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,pred_tree))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.73      0.95      0.82        56
# Moderate levels of lineliness       0.00      0.00      0.00         4
#   Normal levels of loneliness       0.29      0.10      0.15        20
#
#                      accuracy                           0.69        80
#                     macro avg       0.34      0.35      0.32        80
#                  weighted avg       0.58      0.69      0.61        80
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **logistic reg**

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.10,random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(xtrain)
X_test = sc.transform(xtest)

# X_train = xtrain
# X_test = xtest

# %%
from sklearn.linear_model import LogisticRegression
classifierx = LogisticRegression(random_state = 0)
classifierx.fit(X_train, ytrain)
# Out:
# LogisticRegression(random_state=0)

# %%
classifierx.predict(X_test)
# Out:
# array(['Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Normal levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Moderate levels of lineliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Low levels of loneliness', 'Low levels of loneliness',
#        'Normal levels of loneliness', 'Normal levels of loneliness',
#        'Normal levels of loneliness', 'Low levels of loneliness'],
#       dtype=object)

# %%
pred_tree = eclf1.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(ytest,pred_tree)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# 0.45

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,pred_tree)
from sklearn.metrics import ConfusionMatrixDisplay
cmp = ConfusionMatrixDisplay.from_predictions(ytest,pred_tree)
fig, ax = plt.subplots(figsize=(10,10))
cmp.plot(ax=ax)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,pred_tree))
# Out:
#                                precision    recall  f1-score   support
#
#      Low levels of loneliness       0.68      0.46      0.55        56
# Moderate levels of lineliness       0.00      0.00      0.00         4
#   Normal levels of loneliness       0.24      0.50      0.32        20
#
#                      accuracy                           0.45        80
#                     macro avg       0.31      0.32      0.29        80
#                  weighted avg       0.54      0.45      0.47        80
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
